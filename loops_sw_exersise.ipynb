# %%
for  i in range(1,11):
  if(i%3==0):
    continue
  if(i==8):
    break
  else:
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 7

# %%
stu_names = ["San","Ab","Nan","Ria","Vin"]
for i in stu_names:
  print(i)
print(len(stu_names))
print(stu_names[::-1])
# Out:
# San
# Ab
# Nan
# Ria
# Vin
# 5
# ['Vin', 'Ria', 'Nan', 'Ab', 'San']

# %%
student = {
    "name": "Sana",
    "age": 25,
    "major": "cs",
    "GPA": 1
}

print(student.keys())
print(student.values())

for k,v in student.items():
  print(k,v)

print(student.get("email"))
# Out:
# dict_keys(['name', 'age', 'major', 'GPA'])
# dict_values(['Sana', 25, 'cs', 1])
# name Sana
# age 25
# major cs
# GPA 1
# None

# %%
student = {
    "cs":1,
    "eng":1.1,
    "stati":2,
    "sw":1
}

def calculate_average(courses):
  print(sum(courses.values())/len(courses))

calculate_average(student)
# Out:
# 1.275

# %%
products = [{"name":"ghu","price":23,"quanity":2},{"name":"fhyh","price":63,"quanity":4},{"name":"sfgh","price":283,"quanity":27}]

for i in products:
  sum = 0
  if price.value > sum:
    sum = price.value
  subtotal = 1
  for key,value in i.items():
    try:
        subtotal *= int(value)
    except (ValueError, TypeError):
        pass

print(subtotal)
# Out:
# 7641
